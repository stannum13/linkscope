# %% [markdown]
# # Link Walkthrough
#
# Thin notebook that consumes the package API. Core logic lives in `src/photon_link_lab`.

# %%
from photon_link_lab import LinkConfig, ModulatorConfig, simulate_link

result = simulate_link(LinkConfig(n_symbols=1024, pam_order=4), ModulatorConfig(kind="ring"))
result.metrics, result.budget
