# %% [markdown]
# # Calibration And Tuning
#
# This notebook exercises the synthetic measurement and heater tuning workflows through package APIs.

# %%
from pathlib import Path

from photon_link_lab.calibration import fit_ring_from_measurements
from photon_link_lab.datasets import generate_fake_ring_measurements
from photon_link_lab.ml import bayesian_like_heater_search

path = generate_fake_ring_measurements(Path("../data/measured/fake_measured_ring_sweep.csv"))
fit_ring_from_measurements(path), bayesian_like_heater_search(thermal_shift_nm=0.12)
